# %% [markdown]
# # Imports

# %%
import numpy as np
import os
import pandas as pd
import shutil

from tqdm import tqdm
from ml.ma import get_training_data
from warnings import simplefilter

simplefilter(action="ignore", category=pd.errors.PerformanceWarning)
pd.set_option("display.max_columns", None)

# %% [markdown]
# # Utils

# %%
def clean_dir(path):
    """Makes a clean directory, removes all files and folders in the specified path"""
    
    if not os.path.exists(path):
        os.mkdir(path)
    
    for filename in os.listdir(path):
        file_path = os.path.join(path, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print(f"Failed to delete {file_path}. Reason: {e}")

# %% [markdown]
# # Compute Moving Averages

# %% [markdown]
# The logic behind the moving averages functions have been put in their own python package so that we can generate data easily when we want to experiment with various sizes for the window of games. This way, we can have different notebook for different machine learning and deep learning algoeithms and don't have to copy code to generate moving averages. We also want to refrain from saving all the data over and over so we are willing to trade the computational time for the storage. Check out the `ml.ma.ma.py` module to get more details on how the code works and what it's doing. There are detailed docstrings that also explain the parameters and their types. Unfortunately, the docstring doesn't show up within jupyter notebook.

# %%
data = get_training_data(5,
                         ["date", "location", "away", "home", "winner"],
                         "../data/team_data")
# Out:
# Building training data...
# Calculating...      : 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 356/356 [00:25<00:00, 14.04Teams/s]
# Merging...          : 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 356/356 [00:07<00:00, 46.84Teams/s]

# %%
data.head()
# Out:
#          date                                           location  \
# 0  2009-11-25                         Moon Palace Resort, Cancun
# 1  2009-11-28                    UIC Pavilion, Chicago, Illinois
# 2  2009-11-28    Hytche Athletic Center, Princess Anne, Maryland
# 3  2009-11-28  South Padre Island Convention Centre, South Pa...
# 4  2009-11-28    Dunkin' Donuts Center, Providence, Rhode Island
#
#                 away                    home winner  away_assist_percentage  \
# 0           KENTUCKY                STANFORD   Away                    56.0
# 1            LIBERTY         TENNESSEE-STATE   Away                    70.6
# 2           AMERICAN  MARYLAND-EASTERN-SHORE   Home                    52.2
# 3  MISSISSIPPI-STATE            OLD-DOMINION   Away                    57.1
# 4     BOSTON-COLLEGE              PROVIDENCE   Away                    60.6
#
#   away_assists  away_block_percentage away_blocks  away_defensive_rating  \
# 0           14                   22.9           8                   98.5
# 1           12                    5.6           2                   90.9
# 2           12                    5.7           3                   92.9
# 3           12                   12.5           5                   91.7
# 4           20                    4.0           2                  108.5
#
#    away_defensive_rebound_percentage away_defensive_rebounds  \
# 0                               56.8                      22
# 1                               60.0                      21
# 2                               59.5                      24
# 3                               65.7                      23
# 4                               63.4                      28
#
#    away_effective_field_goal_percentage away_field_goal_attempts  \
# 0                                 0.500                       56
# 1                                 0.439                       41
# 2                                 0.471                       52
# 3                                 0.567                       45
# 4                                 0.508                       65
#
#    away_field_goal_percentage away_field_goals  away_free_throw_attempt_rate  \
# 0                       0.446               25                         0.446
# 1                       0.415               17                         0.805
# 2                       0.442               23                         0.269
# 3                       0.467               21                         0.511
# 4                       0.508               33                         0.415
#
#   away_free_throw_attempts  away_free_throw_percentage away_free_throws  \
# 0                       25                       0.680               17
# 1                       33                       0.818               27
# 2                       14                       0.643                9
# 3                       23                       0.783               18
# 4                       27                       0.593               16
#
#   away_losses  away_minutes_played  away_offensive_rating  \
# 0           0                225.0                  110.6
# 1           5                200.0                   95.5
# 2           7                200.0                   82.9
# 3           2                200.0                  115.0
# 4           2                200.0                  115.5
#
#    away_offensive_rebound_percentage away_offensive_rebounds  \
# 0                               55.2                      15
# 1                               39.1                       9
# 2                               33.3                       8
# 3                               35.0                       7
# 4                               47.2                      15
#
#   away_personal_fouls away_points  away_steal_percentage away_steals  \
# 0                  21          73                    7.6           5
# 1                  12          63                   12.1           8
# 2                  19          58                    5.7           4
# 3                  10          69                    5.0           3
# 4                  14          82                    1.4           1
#
#    away_three_point_attempt_rate  away_three_point_field_goal_attempts  \
# 0                          0.339                                  19.0
# 1                          0.268                                  11.0
# 2                          0.250                                  13.0
# 3                          0.511                                  23.0
# 4                          0.154                                  10.0
#
#    away_three_point_field_goal_percentage  away_three_point_field_goals  \
# 0                                   0.316                           6.0
# 1                                   0.182                           2.0
# 2                                   0.231                           3.0
# 3                                   0.391                           9.0
# 4                                   0.000                           0.0
#
#    away_total_rebound_percentage away_total_rebounds  \
# 0                           56.1                  37
# 1                           51.7                  30
# 2                           47.8                  32
# 3                           54.5                  30
# 4                           55.8                  43
#
#    away_true_shooting_percentage  away_turnover_percentage away_turnovers  \
# 0                          0.538                      18.3             15
# 1                          0.556                      24.5             17
# 2                          0.494                      27.4             22
# 3                          0.617                      16.6              9
# 4                          0.527                      11.5             10
#
#    away_two_point_field_goal_attempts  away_two_point_field_goal_percentage  \
# 0                                37.0                                 0.514
# 1                                30.0                                 0.500
# 2                                39.0                                 0.513
# 3                                22.0                                 0.545
# 4                                55.0                                 0.600
#
#    away_two_point_field_goals  away_win_percentage away_wins  \
# 0                        19.0                1.000         6
# 1                        15.0                0.375         3
# 2                        20.0                0.000         0
# 3                        12.0                0.667         4
# 4                        33.0                0.667         4
#
#    away_assist_percentage_sma  away_assist_percentage_cma  \
# 0                       53.00                   53.000000
# 1                       49.02                   51.516667
# 2                       64.06                   62.466667
# 3                       48.08                   48.080000
# 4                       56.12                   56.120000
#
#    away_assist_percentage_ema  away_assists_sma  away_assists_cma  \
# 0                   55.785185              15.2         15.200000
# 1                   56.620576               9.6         10.666667
# 2                   63.579835              14.2         13.833333
# 3                   48.864198              11.8         11.800000
# 4                   53.314815              15.6         15.600000
#
#    away_assists_ema  away_block_percentage_sma  away_block_percentage_cma  \
# 0         15.345679                      24.46                  24.460000
# 1         12.275720                       5.54                   5.833333
# 2         13.954733                       9.14                   7.616667
# 3         11.407407                      20.18                  20.180000
# 4         14.641975                       8.54                   8.540000
#
#    away_block_percentage_ema  away_blocks_sma  away_blocks_cma  \
# 0                  22.244444              8.6         8.600000
# 1                   5.570782              2.2         2.333333
# 2                   8.929218              3.8         3.166667
# 3                  18.004938              8.6         8.600000
# 4                   7.074074              3.6         3.600000
#
#    away_blocks_ema  away_defensive_rating_sma  away_defensive_rating_cma  \
# 0         8.271605                      91.48                  91.480000
# 1         2.000000                     105.24                 106.050000
# 2         3.971193                     103.34                 103.316667
# 3         7.543210                      94.88                  94.880000
# 4         3.012346                      98.92                  98.920000
#
#    away_defensive_rating_ema  away_defensive_rebound_percentage_sma  \
# 0                  85.281481                                  67.68
# 1                 101.560494                                  63.34
# 2                 103.181481                                  68.84
# 3                  97.330864                                  76.50
# 4                 106.771605                                  70.14
#
#    away_defensive_rebound_percentage_cma  \
# 0                              67.680000
# 1                              63.466667
# 2                              67.016667
# 3                              76.500000
# 4                              70.140000
#
#    away_defensive_rebound_percentage_ema  away_defensive_rebounds_sma  \
# 0                              68.417284                         27.6
# 1                              66.108230                         22.6
# 2                              69.981893                         24.8
# 3                              76.409877                         27.2
# 4                              70.474074                         23.6
#
#    away_defensive_rebounds_cma  away_defensive_rebounds_ema  \
# 0                    27.600000                    29.407407
# 1                    23.166667                    23.864198
# 2                    24.333333                    26.386831
# 3                    27.200000                    25.901235
# 4                    23.600000                    21.691358
#
#    away_effective_field_goal_percentage_sma  \
# 0                                    0.5810
# 1                                    0.4100
# 2                                    0.4594
# 3                                    0.5108
# 4                                    0.5412
#
#    away_effective_field_goal_percentage_cma  \
# 0                                  0.581000
# 1                                  0.426500
# 2                                  0.458167
# 3                                  0.510800
# 4                                  0.541200
#
#    away_effective_field_goal_percentage_ema  away_field_goal_attempts_sma  \
# 0                                  0.578259                          54.6
# 1                                  0.448321                          49.8
# 2                                  0.472058                          53.8
# 3                                  0.498827                          58.2
# 4                                  0.550568                          57.6
#
#    away_field_goal_attempts_cma  away_field_goal_attempts_ema  \
# 0                     54.600000                     53.061728
# 1                     51.166667                     52.530864
# 2                     53.500000                     51.851852
# 3                     58.200000                     57.333333
# 4                     57.600000                     55.382716
#
#    away_field_goal_percentage_sma  away_field_goal_percentage_cma  \
# 0                          0.5260                        0.526000
# 1                          0.3728                        0.382500
# 2                          0.4142                        0.415667
# 3                          0.4318                        0.431800
# 4                          0.4864                        0.486400
#
#    away_field_goal_percentage_ema  away_field_goals_sma  away_field_goals_cma  \
# 0                        0.525259                  28.8             28.800000
# 1                        0.401724                  18.8             19.833333
# 2                        0.424683                  22.2             22.166667
# 3                        0.418852                  25.2             25.200000
# 4                        0.495926                  27.4             27.400000
#
#    away_field_goals_ema  away_free_throw_attempt_rate_sma  \
# 0             27.925926                            0.5462
# 1             21.312757                            0.3940
# 2             21.946502                            0.3294
# 3             24.123457                            0.3064
# 4             26.987654                            0.3898
#
#    away_free_throw_attempt_rate_cma  away_free_throw_attempt_rate_ema  \
# 0                            0.5462                          0.594457
# 1                            0.3830                          0.391119
# 2                            0.3225                          0.372374
# 3                            0.3064                          0.318519
# 4                            0.3898                          0.405160
#
#    away_free_throw_attempts_sma  away_free_throw_attempts_cma  \
# 0                          28.8                     28.800000
# 1                          19.6                     19.500000
# 2                          17.6                     17.166667
# 3                          17.8                     17.800000
# 4                          22.0                     22.000000
#
#    away_free_throw_attempts_ema  away_free_throw_percentage_sma  \
# 0                     30.086420                          0.6634
# 1                     20.407407                          0.7106
# 2                     19.230453                          0.6550
# 3                     18.160494                          0.6822
# 4                     22.061728                          0.7048
#
#    away_free_throw_percentage_cma  away_free_throw_percentage_ema  \
# 0                        0.663400                        0.676074
# 1                        0.706167                        0.729984
# 2                        0.701333                        0.642066
# 3                        0.682200                        0.676136
# 4                        0.704800                        0.711864
#
#    away_free_throws_sma  away_free_throws_cma  away_free_throws_ema  \
# 0                  19.2             19.200000             20.395062
# 1                  14.0             13.833333             14.909465
# 2                  10.6             11.166667             12.037037
# 3                  12.4             12.400000             12.580247
# 4                  16.0             16.000000             16.222222
#
#    away_losses_sma  away_losses_cma  away_losses_ema  away_minutes_played_sma  \
# 0              0.0         0.000000         0.000000                    200.0
# 1              3.8         3.333333         3.930041                    200.0
# 2              4.0         3.500000         4.263374                    200.0
# 3              1.2         1.200000         1.333333                    200.0
# 4              0.8         0.800000         1.037037                    200.0
#
#    away_minutes_played_cma  away_minutes_played_ema  \
# 0               200.000000               200.000000
# 1               200.666667               200.526749
# 2               200.000000               200.000000
# 3               200.000000               200.000000
# 4               200.000000               200.000000
#
#    away_offensive_rating_sma  away_offensive_rating_cma  \
# 0                     113.42                 113.420000
# 1                      80.86                  84.766667
# 2                      89.40                  90.633333
# 3                     106.68                 106.680000
# 4                     115.62                 115.620000
#
#    away_offensive_rating_ema  away_offensive_rebound_percentage_sma  \
# 0                 111.638272                                  52.34
# 1                  93.186420                                  32.30
# 2                  89.367490                                  33.66
# 3                 106.477778                                  38.46
# 4                 117.633333                                  47.12
#
#    away_offensive_rebound_percentage_cma  \
# 0                              52.340000
# 1                              32.633333
# 2                              33.400000
# 3                              38.460000
# 4                              47.120000
#
#    away_offensive_rebound_percentage_ema  away_offensive_rebounds_sma  \
# 0                              51.337037                         13.6
# 1                              38.954733                          8.4
# 2                              33.743210                          9.0
# 3                              41.604938                         11.2
# 4                              48.576543                         11.8
#
#    away_offensive_rebounds_cma  away_offensive_rebounds_ema  \
# 0                    13.600000                    12.839506
# 1                     8.833333                    10.403292
# 2                     9.000000                     8.794239
# 3                    11.200000                    12.481481
# 4                    11.800000                    11.777778
#
#    away_personal_fouls_sma  away_personal_fouls_cma  away_personal_fouls_ema  \
# 0                     16.6                16.600000                17.259259
# 1                     15.4                16.333333                16.341564
# 2                     17.6                18.000000                18.255144
# 3                     12.8                12.800000                13.691358
# 4                     16.8                16.800000                17.197531
#
#    away_points_sma  away_points_cma  away_points_ema  \
# 0             82.8        82.800000        81.814815
# 1             55.4        58.166667        62.543210
# 2             59.8        60.000000        60.781893
# 3             72.0        72.000000        69.975309
# 4             77.0        77.000000        76.209877
#
#    away_steal_percentage_sma  away_steal_percentage_cma  \
# 0                       8.86                   8.860000
# 1                       9.88                   9.433333
# 2                       5.74                   6.100000
# 3                       7.76                   7.760000
# 4                       5.22                   5.220000
#
#    away_steal_percentage_ema  away_steals_sma  away_steals_cma  \
# 0                   8.161728              6.4              6.4
# 1                   9.187654              6.8              6.5
# 2                   5.137449              3.8              4.0
# 3                   6.162963              5.4              5.4
# 4                   4.750617              3.6              3.6
#
#    away_steals_ema  away_three_point_attempt_rate_sma  \
# 0         5.975309                             0.2888
# 1         6.156379                             0.3394
# 2         3.427984                             0.2618
# 3         4.246914                             0.4088
# 4         3.209877                             0.2786
#
#    away_three_point_attempt_rate_cma  away_three_point_attempt_rate_ema  \
# 0                           0.288800                           0.288123
# 1                           0.337500                           0.354848
# 2                           0.256667                           0.264062
# 3                           0.408800                           0.418728
# 4                           0.278600                           0.276148
#
#    away_three_point_field_goal_attempts_sma  \
# 0                                      15.8
# 1                                      17.0
# 2                                      14.0
# 3                                      23.8
# 4                                      16.2
#
#    away_three_point_field_goal_attempts_cma  \
# 0                                 15.800000
# 1                                 17.333333
# 2                                 13.666667
# 3                                 23.800000
# 4                                 16.200000
#
#    away_three_point_field_goal_attempts_ema  \
# 0                                 15.320988
# 1                                 18.662551
# 2                                 13.625514
# 3                                 23.987654
# 4                                 15.456790
#
#    away_three_point_field_goal_percentage_sma  \
# 0                                      0.3922
# 1                                      0.2144
# 2                                      0.3418
# 3                                      0.3878
# 4                                      0.3862
#
#    away_three_point_field_goal_percentage_cma  \
# 0                                    0.392200
# 1                                    0.257667
# 2                                    0.326500
# 3                                    0.387800
# 4                                    0.386200
#
#    away_three_point_field_goal_percentage_ema  \
# 0                                    0.376802
# 1                                    0.263885
# 2                                    0.353198
# 3                                    0.382741
# 4                                    0.384568
#
#    away_three_point_field_goals_sma  away_three_point_field_goals_cma  \
# 0                               6.0                          6.000000
# 1                               3.8                          4.666667
# 2                               4.8                          4.500000
# 3                               9.2                          9.200000
# 4                               6.2                          6.200000
#
#    away_three_point_field_goals_ema  away_total_rebound_percentage_sma  \
# 0                          5.567901                              61.30
# 1                          5.008230                              48.68
# 2                          4.851852                              51.80
# 3                          9.148148                              57.88
# 4                          6.012346                              58.90
#
#    away_total_rebound_percentage_cma  away_total_rebound_percentage_ema  \
# 0                              61.30                          61.932099
# 1                              48.90                          53.292593
# 2                              51.00                          53.095885
# 3                              57.88                          58.996296
# 4                              58.90                          59.367901
#
#    away_total_rebounds_sma  away_total_rebounds_cma  away_total_rebounds_ema  \
# 0                     41.2                41.200000                42.246914
# 1                     31.0                32.000000                34.267490
# 2                     33.8                33.333333                35.181070
# 3                     38.4                38.400000                38.382716
# 4                     35.4                35.400000                33.469136
#
#    away_true_shooting_percentage_sma  away_true_shooting_percentage_cma  \
# 0                             0.6054                           0.605400
# 1                             0.4632                           0.475500
# 2                             0.4816                           0.487333
# 3                             0.5404                           0.540400
# 4                             0.5734                           0.573400
#
#    away_true_shooting_percentage_ema  away_turnover_percentage_sma  \
# 0                           0.607519                         22.44
# 1                           0.498609                         24.44
# 2                           0.499449                         20.36
# 3                           0.530877                         16.94
# 4                           0.584654                         15.96
#
#    away_turnover_percentage_cma  away_turnover_percentage_ema  \
# 0                     22.440000                     22.992593
# 1                     23.433333                     20.911111
# 2                     20.000000                     22.592593
# 3                     16.940000                     17.164198
# 4                     15.960000                     16.402469
#
#    away_turnovers_sma  away_turnovers_cma  away_turnovers_ema  \
# 0                18.8           18.800000           18.925926
# 1                18.8           18.000000           16.069959
# 2                15.8           15.166667           17.526749
# 3                13.2           13.200000           13.370370
# 4                12.4           12.400000           12.407407
#
#    away_two_point_field_goal_attempts_sma  \
# 0                                    38.8
# 1                                    32.8
# 2                                    39.8
# 3                                    34.4
# 4                                    41.4
#
#    away_two_point_field_goal_attempts_cma  \
# 0                               38.800000
# 1                               33.833333
# 2                               39.833333
# 3                               34.400000
# 4                               41.400000
#
#    away_two_point_field_goal_attempts_ema  \
# 0                               37.740741
# 1                               33.868313
# 2                               38.226337
# 3                               33.345679
# 4                               39.925926
#
#    away_two_point_field_goal_percentage_sma  \
# 0                                    0.5898
# 1                                    0.4554
# 2                                    0.4380
# 3                                    0.4594
# 4                                    0.5200
#
#    away_two_point_field_goal_percentage_cma  \
# 0                                  0.589800
# 1                                  0.447833
# 2                                  0.444167
# 3                                  0.459400
# 4                                  0.520000
#
#    away_two_point_field_goal_percentage_ema  away_two_point_field_goals_sma  \
# 0                                  0.592247                            22.8
# 1                                  0.479901                            15.0
# 2                                  0.447519                            17.4
# 3                                  0.440716                            16.0
# 4                                  0.531914                            21.2
#
#    away_two_point_field_goals_cma  away_two_point_field_goals_ema  \
# 0                       22.800000                       22.358025
# 1                       15.166667                       16.304527
# 2                       17.666667                       17.094650
# 3                       16.000000                       14.975309
# 4                       21.200000                       20.975309
#
#    away_win_percentage_sma  away_win_percentage_cma  away_win_percentage_ema  \
# 0                   1.0000                   1.0000                 1.000000
# 1                   0.2472                   0.2060                 0.208691
# 2                   0.0000                   0.0000                 0.000000
# 3                   0.5034                   0.5034                 0.514864
# 4                   0.8034                   0.8034                 0.761778
#
#    away_wins_sma  away_wins_cma  away_wins_ema  home_assist_percentage  \
# 0            3.0            3.0       3.395062                    55.0
# 1            1.2            1.0       1.201646                    54.5
# 2            0.0            0.0       0.000000                    48.0
# 3            1.8            1.8       2.061728                    63.6
# 4            2.2            2.2       2.358025                    46.7
#
#   home_assists  home_block_percentage home_blocks  home_defensive_rating  \
# 0           11                    5.4           2                  110.6
# 1           12                   10.0           3                   95.5
# 2           12                    5.1           2                   82.9
# 3           14                    0.0           0                  115.0
# 4           14                   14.5           8                  115.5
#
#    home_defensive_rebound_percentage home_defensive_rebounds  \
# 0                               44.8                      16
# 1                               60.9                      18
# 2                               66.7                      21
# 3                               65.0                      17
# 4                               52.8                      20
#
#    home_effective_field_goal_percentage home_field_goal_attempts  \
# 0                                 0.427                       55
# 1                                 0.417                       60
# 2                                 0.421                       63
# 3                                 0.422                       58
# 4                                 0.473                       74
#
#    home_field_goal_percentage home_field_goals  home_free_throw_attempt_rate  \
# 0                       0.364               20                         0.473
# 1                       0.367               22                         0.200
# 2                       0.397               25                         0.302
# 3                       0.379               22                         0.138
# 4                       0.405               30                         0.176
#
#   home_free_throw_attempts  home_free_throw_percentage home_free_throws  \
# 0                       26                       0.692               18
# 1                       12                       0.833               10
# 2                       19                       0.632               12
# 3                        8                       0.750                6
# 4                       13                       0.538                7
#
#   home_losses  home_minutes_played  home_offensive_rating  \
# 0           3                225.0                   98.5
# 1           5                200.0                   90.9
# 2           5                200.0                   92.9
# 3           2                200.0                   91.7
# 4           2                200.0                  108.5
#
#    home_offensive_rebound_percentage home_offensive_rebounds  \
# 0                               43.2                      13
# 1                               40.0                      10
# 2                               40.5                      14
# 3                               34.3                       8
# 4                               36.6                      14
#
#   home_personal_fouls home_points  home_steal_percentage home_steals  \
# 0                  22          65                    9.1           6
# 1                  23          60                   10.6           7
# 2                  17          65                   14.3          10
# 3                  23          55                    8.3           5
# 4                  21          77                    9.9           7
#
#    home_three_point_attempt_rate  home_three_point_field_goal_attempts  \
# 0                          0.364                                  20.0
# 1                          0.400                                  24.0
# 2                          0.159                                  10.0
# 3                          0.310                                  18.0
# 4                          0.324                                  24.0
#
#    home_three_point_field_goal_percentage  home_three_point_field_goals  \
# 0                                   0.350                           7.0
# 1                                   0.250                           6.0
# 2                                   0.300                           3.0
# 3                                   0.278                           5.0
# 4                                   0.417                          10.0
#
#    home_total_rebound_percentage home_total_rebounds  \
# 0                           43.9                  29
# 1                           48.3                  28
# 2                           52.2                  35
# 3                           45.5                  25
# 4                           44.2                  34
#
#    home_true_shooting_percentage  home_turnover_percentage home_turnovers  \
# 0                          0.483                      17.4             12
# 1                          0.457                      17.7             13
# 2                          0.451                      15.4             13
# 3                          0.445                      14.0             10
# 4                          0.480                       7.0              6
#
#    home_two_point_field_goal_attempts  home_two_point_field_goal_percentage  \
# 0                                35.0                                 0.371
# 1                                36.0                                 0.444
# 2                                53.0                                 0.415
# 3                                40.0                                 0.425
# 4                                50.0                                 0.400
#
#    home_two_point_field_goals  home_win_percentage home_wins  \
# 0                        13.0                0.500         3
# 1                        16.0                0.167         1
# 2                        22.0                0.167         1
# 3                        17.0                0.667         4
# 4                        20.0                0.667         4
#
#    home_assist_percentage_sma  home_assist_percentage_cma  \
# 0                       55.44                       55.44
# 1                       54.72                       54.72
# 2                       54.46                       54.46
# 3                       63.76                       63.76
# 4                       44.18                       44.18
#
#    home_assist_percentage_ema  home_assists_sma  home_assists_cma  \
# 0                   55.229630              14.4              14.4
# 1                   54.185185              12.6              12.6
# 2                   52.204938              10.4              10.4
# 3                   65.154321              17.4              17.4
# 4                   45.950617              14.0              14.0
#
#    home_assists_ema  home_block_percentage_sma  home_block_percentage_cma  \
# 0         14.111111                       5.28                       5.28
# 1         12.925926                       6.94                       6.94
# 2          9.925926                       4.40                       4.40
# 3         16.197531                       7.84                       7.84
# 4         15.222222                      13.52                      13.52
#
#    home_block_percentage_ema  home_blocks_sma  home_blocks_cma  \
# 0                   4.504938              2.0              2.0
# 1                   5.856790              2.0              2.0
# 2                   3.781481              1.6              1.6
# 3                   7.446914              2.8              2.8
# 4                  12.611111              5.6              5.6
#
#    home_blocks_ema  home_defensive_rating_sma  home_defensive_rating_cma  \
# 0         1.691358                      92.76                      92.76
# 1         1.765432                     111.08                     111.08
# 2         1.320988                     119.42                     119.42
# 3         2.641975                      82.18                      82.18
# 4         5.320988                      93.26                      93.26
#
#    home_defensive_rating_ema  home_defensive_rebound_percentage_sma  \
# 0                  92.076543                                  75.00
# 1                 109.480247                                  56.52
# 2                 121.093827                                  61.14
# 3                  85.990123                                  68.18
# 4                  90.390123                                  63.76
#
#    home_defensive_rebound_percentage_cma  \
# 0                                  75.00
# 1                                  56.52
# 2                                  61.14
# 3                                  68.18
# 4                                  63.76
#
#    home_defensive_rebound_percentage_ema  home_defensive_rebounds_sma  \
# 0                              75.785185                         23.8
# 1                              56.780247                         17.8
# 2                              63.783951                         19.6
# 3                              65.302469                         24.0
# 4                              63.209877                         26.2
#
#    home_defensive_rebounds_cma  home_defensive_rebounds_ema  \
# 0                         23.8                    24.259259
# 1                         17.8                    18.345679
# 2                         19.6                    19.827160
# 3                         24.0                    22.839506
# 4                         26.2                    26.111111
#
#    home_effective_field_goal_percentage_sma  \
# 0                                    0.5010
# 1                                    0.4700
# 2                                    0.4140
# 3                                    0.5410
# 4                                    0.4846
#
#    home_effective_field_goal_percentage_cma  \
# 0                                    0.5010
# 1                                    0.4700
# 2                                    0.4140
# 3                                    0.5410
# 4                                    0.4846
#
#    home_effective_field_goal_percentage_ema  home_field_goal_attempts_sma  \
# 0                                  0.497790                          58.6
# 1                                  0.480593                          56.6
# 2                                  0.406852                          52.2
# 3                                  0.531852                          55.4
# 4                                  0.499568                          72.6
#
#    home_field_goal_attempts_cma  home_field_goal_attempts_ema  \
# 0                          58.6                     58.074074
# 1                          56.6                     56.518519
# 2                          52.2                     52.728395
# 3                          55.4                     51.580247
# 4                          72.6                     73.654321
#
#    home_field_goal_percentage_sma  home_field_goal_percentage_cma  \
# 0                          0.4342                          0.4342
# 1                          0.4074                          0.4074
# 2                          0.3654                          0.3654
# 3                          0.4894                          0.4894
# 4                          0.4200                          0.4200
#
#    home_field_goal_percentage_ema  home_field_goals_sma  home_field_goals_cma  \
# 0                        0.429049                  25.6                  25.6
# 1                        0.421605                  23.0                  23.0
# 2                        0.360926                  19.0                  19.0
# 3                        0.480321                  27.4                  27.4
# 4                        0.431481                  30.6                  30.6
#
#    home_field_goals_ema  home_free_throw_attempt_rate_sma  \
# 0             25.123457                            0.3894
# 1             23.790123                            0.2700
# 2             18.962963                            0.4338
# 3             25.024691                            0.3766
# 4             31.913580                            0.3316
#
#    home_free_throw_attempt_rate_cma  home_free_throw_attempt_rate_ema  \
# 0                            0.3894                          0.373136
# 1                            0.2700                          0.271901
# 2                            0.4338                          0.451420
# 3                            0.3766                          0.431667
# 4                            0.3316                          0.331259
#
#    home_free_throw_attempts_sma  home_free_throw_attempts_cma  \
# 0                          22.6                          22.6
# 1                          15.2                          15.2
# 2                          22.4                          22.4
# 3                          19.4                          19.4
# 4                          24.0                          24.0
#
#    home_free_throw_attempts_ema  home_free_throw_percentage_sma  \
# 0                     21.567901                          0.6540
# 1                     15.308642                          0.6390
# 2                     23.530864                          0.6358
# 3                     20.987654                          0.6720
# 4                     24.296296                          0.6604
#
#    home_free_throw_percentage_cma  home_free_throw_percentage_ema  \
# 0                          0.6540                        0.639074
# 1                          0.6390                        0.672556
# 2                          0.6358                        0.634691
# 3                          0.6720                        0.678247
# 4                          0.6604                        0.668420
#
#    home_free_throws_sma  home_free_throws_cma  home_free_throws_ema  \
# 0                  15.2                  15.2             14.333333
# 1                   9.8                   9.8             10.382716
# 2                  13.6                  13.6             14.358025
# 3                  13.6                  13.6             14.703704
# 4                  15.8                  15.8             16.234568
#
#    home_losses_sma  home_losses_cma  home_losses_ema  home_minutes_played_sma  \
# 0              1.6              1.6         1.703704                    200.4
# 1              2.8              2.8         3.061728                    200.0
# 2              3.0              3.0         3.395062                    200.0
# 3              0.2              0.2         0.333333                    200.0
# 4              0.4              0.4         0.555556                    200.0
#
#    home_minutes_played_cma  home_minutes_played_ema  \
# 0                    200.4               200.530864
# 1                    200.0               200.000000
# 2                    200.0               200.000000
# 3                    200.0               200.000000
# 4                    200.0               200.000000
#
#    home_offensive_rating_sma  home_offensive_rating_cma  \
# 0                     102.50                     102.50
# 1                      90.22                      90.22
# 2                      85.54                      85.54
# 3                     114.88                     114.88
# 4                     116.12                     116.12
#
#    home_offensive_rating_ema  home_offensive_rebound_percentage_sma  \
# 0                 101.367901                                  23.88
# 1                  93.345679                                  41.92
# 2                  86.409877                                  30.68
# 3                 109.819753                                  51.60
# 4                 117.651852                                  51.64
#
#    home_offensive_rebound_percentage_cma  \
# 0                                  23.88
# 1                                  41.92
# 2                                  30.68
# 3                                  51.60
# 4                                  51.64
#
#    home_offensive_rebound_percentage_ema  home_offensive_rebounds_sma  \
# 0                              24.370370                          7.8
# 1                              45.044444                         11.2
# 2                              31.037037                          9.0
# 3                              51.834568                         12.6
# 4                              51.825926                         19.4
#
#    home_offensive_rebounds_cma  home_offensive_rebounds_ema  \
# 0                          7.8                     8.148148
# 1                         11.2                    12.012346
# 2                          9.0                     9.432099
# 3                         12.6                    11.851852
# 4                         19.4                    18.975309
#
#    home_personal_fouls_sma  home_personal_fouls_cma  home_personal_fouls_ema  \
# 0                     16.0                     16.0                16.123457
# 1                     20.8                     20.8                20.271605
# 2                     18.8                     18.8                18.592593
# 3                     16.6                     16.6                16.975309
# 4                     19.8                     19.8                20.728395
#
#    home_points_sma  home_points_cma  home_points_ema  \
# 0             74.2             74.2        72.555556
# 1             62.8             62.8        64.555556
# 2             56.6             56.6        57.037037
# 3             74.2             74.2        70.012346
# 4             86.4             86.4        90.172840
#
#    home_steal_percentage_sma  home_steal_percentage_cma  \
# 0                       8.80                       8.80
# 1                      14.38                      14.38
# 2                       6.30                       6.30
# 3                      10.78                      10.78
# 4                      12.52                      12.52
#
#    home_steal_percentage_ema  home_steals_sma  home_steals_cma  \
# 0                   9.066667              6.4              6.4
# 1                  14.229630             10.2             10.2
# 2                   5.969136              4.2              4.2
# 3                  10.235802              7.0              7.0
# 4                  14.170370              9.6              9.6
#
#    home_steals_ema  home_three_point_attempt_rate_sma  \
# 0         6.530864                             0.3462
# 1        10.012346                             0.3428
# 2         3.975309                             0.3244
# 3         6.567901                             0.2390
# 4        11.197531                             0.3980
#
#    home_three_point_attempt_rate_cma  home_three_point_attempt_rate_ema  \
# 0                             0.3462                           0.339383
# 1                             0.3428                           0.325037
# 2                             0.3244                           0.328235
# 3                             0.2390                           0.250444
# 4                             0.3980                           0.379111
#
#    home_three_point_field_goal_attempts_sma  \
# 0                                      20.4
# 1                                      19.4
# 2                                      17.0
# 3                                      13.0
# 4                                      28.8
#
#    home_three_point_field_goal_attempts_cma  \
# 0                                      20.4
# 1                                      19.4
# 2                                      17.0
# 3                                      13.0
# 4                                      28.8
#
#    home_three_point_field_goal_attempts_ema  \
# 0                                 19.876543
# 1                                 18.382716
# 2                                 17.345679
# 3                                 12.654321
# 4                                 27.888889
#
#    home_three_point_field_goal_percentage_sma  \
# 0                                      0.3830
# 1                                      0.3616
# 2                                      0.3114
# 3                                      0.4340
# 4                                      0.3278
#
#    home_three_point_field_goal_percentage_cma  \
# 0                                      0.3830
# 1                                      0.3616
# 2                                      0.3114
# 3                                      0.4340
# 4                                      0.3278
#
#    home_three_point_field_goal_percentage_ema  \
# 0                                    0.404519
# 1                                    0.360346
# 2                                    0.288222
# 3                                    0.405012
# 4                                    0.363407
#
#    home_three_point_field_goals_sma  home_three_point_field_goals_cma  \
# 0                               7.8                               7.8
# 1                               7.0                               7.0
# 2                               5.0                               5.0
# 3                               5.8                               5.8
# 4                               9.4                               9.4
#
#    home_three_point_field_goals_ema  home_total_rebound_percentage_sma  \
# 0                          7.975309                              47.66
# 1                          6.592593                              47.42
# 2                          4.753086                              44.76
# 3                          5.259259                              60.12
# 4                         10.111111                              57.36
#
#    home_total_rebound_percentage_cma  home_total_rebound_percentage_ema  \
# 0                              47.66                          48.438272
# 1                              47.42                          48.972840
# 2                              44.76                          45.819753
# 3                              60.12                          58.825926
# 4                              57.36                          57.196296
#
#    home_total_rebounds_sma  home_total_rebounds_cma  home_total_rebounds_ema  \
# 0                     31.6                     31.6                32.407407
# 1                     29.0                     29.0                30.358025
# 2                     28.6                     28.6                29.259259
# 3                     36.6                     36.6                34.691358
# 4                     45.6                     45.6                45.086420
#
#    home_true_shooting_percentage_sma  home_true_shooting_percentage_cma  \
# 0                             0.5310                             0.5310
# 1                             0.4932                             0.4932
# 2                             0.4518                             0.4518
# 3                             0.5720                             0.5720
# 4                             0.5142                             0.5142
#
#    home_true_shooting_percentage_ema  home_turnover_percentage_sma  \
# 0                           0.525432                         13.32
# 1                           0.506667                         23.46
# 2                           0.447160                         18.64
# 3                           0.567667                         19.50
# 4                           0.528358                         12.10
#
#    home_turnover_percentage_cma  home_turnover_percentage_ema  \
# 0                         13.32                     13.824691
# 1                         23.46                     23.519753
# 2                         18.64                     17.402469
# 3                         19.50                     21.909877
# 4                         12.10                     13.095062
#
#    home_turnovers_sma  home_turnovers_cma  home_turnovers_ema  \
# 0                10.2                10.2           10.469136
# 1                18.6                18.6           18.790123
# 2                14.0                14.0           13.123457
# 3                15.2                15.2           16.728395
# 4                11.6                11.6           12.950617
#
#    home_two_point_field_goal_attempts_sma  \
# 0                                    38.2
# 1                                    37.2
# 2                                    35.2
# 3                                    42.4
# 4                                    43.8
#
#    home_two_point_field_goal_attempts_cma  \
# 0                                    38.2
# 1                                    37.2
# 2                                    35.2
# 3                                    42.4
# 4                                    43.8
#
#    home_two_point_field_goal_attempts_ema  \
# 0                               38.197531
# 1                               38.135802
# 2                               35.382716
# 3                               38.925926
# 4                               45.765432
#
#    home_two_point_field_goal_percentage_sma  \
# 0                                    0.4670
# 1                                    0.4298
# 2                                    0.3992
# 3                                    0.5072
# 4                                    0.4870
#
#    home_two_point_field_goal_percentage_cma  \
# 0                                    0.4670
# 1                                    0.4298
# 2                                    0.3992
# 3                                    0.5072
# 4                                    0.4870
#
#    home_two_point_field_goal_percentage_ema  home_two_point_field_goals_sma  \
# 0                                  0.449235                            17.8
# 1                                  0.450247                            16.0
# 2                                  0.403074                            14.0
# 3                                  0.502222                            21.6
# 4                                  0.480951                            21.2
#
#    home_two_point_field_goals_cma  home_two_point_field_goals_ema  \
# 0                            17.8                       17.148148
# 1                            16.0                       17.197531
# 2                            14.0                       14.209877
# 3                            21.6                       19.765432
# 4                            21.2                       21.802469
#
#    home_win_percentage_sma  home_win_percentage_cma  home_win_percentage_ema  \
# 0                   0.3866                   0.3866                 0.409827
# 1                   0.0400                   0.0400                 0.066667
# 2                   0.0000                   0.0000                 0.000000
# 3                   0.9600                   0.9600                 0.933333
# 4                   0.9100                   0.9100                 0.877778
#
#    home_wins_sma  home_wins_cma  home_wins_ema
# 0            1.4            1.4       1.691358
# 1            0.2            0.2       0.333333
# 2            0.0            0.0       0.000000
# 3            2.8            2.8       3.061728
# 4            2.6            2.6       2.839506
